# %% [markdown]
# # Word/Sentence Generation using Markov's model

# %%
#We only need to import numpy for its random function, but we can also import pretty print to better visualize our markov chain
import numpy as np
import pprint

#File where the text is. Make sure it's in the same directory as the code
training_file = "chainsmokers.txt"

#how many words we want our song to be. The average song is usually between 250-300 words (not including unique words)
number_of_words = 280

# %% [markdown]
# ## Setting up helper functions

# %% [markdown]
# Load the file using the with...open function and use the "r" for read only

# %%
def load_file():
    with open(training_file, "r") as file:
        song = file.read()
    
    return song

# %% [markdown]
# Now it's time to code the engine of our program: the Markov Chain. This will be a dictionary with a single word as the key, and a list of all the subsequent words as its value.

# %%
def build_chain(song):
    #split text file into a list of single words/tokens
    tokens = song.split()
    index = 1
    chain = {}
    #iterate through the list and add each word as a key or value until we reach the last word, the ':' after index means starting at index and incrementing to values after
    for word in tokens[index:]:
        #Because we consider word pairs, we start at the second word in the list and decrement down to index - 1 as the key
        key = tokens[index - 1]
        if key in chain:
            chain[key].append(word)
        else:
            chain[key] = [word]
        index += 1

    return chain

#not necessary, but pretty printing our dictionary gives us a better view of how this chain building works
pprint.pprint(chain)
# Out:
# {'"Hey,': ['whatcha', 'whatcha', 'whatcha'],
#  '"How': ['Could'],
#  '"I': ["don't",
#         'never',
#         'never',
#         "don't",
#         'never',
#         'never',
#         "don't",
#         'never',
#         'never'],
#  '"Wow': ['If'],
#  "'Cause": ['I', 'I'],
#  '(If': ['we', 'we', 'we', 'we'],
#  '(we': ["ain't", "ain't", "ain't"],
#  'Am': ['I', 'I'],
#  'And': ['four',
#          'I',
#          'four',
#          'I',
#          'almost',
#          'all',
#          'almost',
#          'all',
#          'almost',
#          'all',
#          'I',
#          'I',
#          'you',
#          'you',
#          'I',
#          'you',
#          'you',
#          'I',
#          'you',
#          'you'],
#  'At': ['least'],
#  'Bite': ['that', 'that', 'that'],
#  'Blink-182': ['song'],
#  'Boulder': ['We', 'We', 'We'],
#  'Bring': ['it', 'it'],
#  'Broke': ['kids', 'kids'],
#  'But': ['I', 'we', "it's", "it's", "it's"],
#  'Can': ['I', 'I', 'I', 'I', 'I', 'I'],
#  'Caught,': ['we'],
#  'Come': ['on,', 'on,'],
#  'Could': ['I'],
#  "Don't": ['let', 'worry,', 'worry,', 'worry,', 'let', 'let'],
#  'Drunk': ['on'],
#  'Fought': ['about'],
#  'From': ['your', 'your', 'your'],
#  'Getting': ['drunk'],
#  'Hey,': ['I', 'you'],
#  'I': ['was',
#        'met',
#        'drink',
#        'hope',
#        'never',
#        'know',
#        "can't",
#        "can't",
#        'know',
#        'met',
#        'forget',
#        'left',
#        'was',
#        'know',
#        "can't",
#        "can't",
#        'know',
#        'know',
#        'go',
#        'wrecked',
#        'hope',
#        'go',
#        'wrecked',
#        'go',
#        'wrecked',
#        'thought,',
#        'could',
#        "don't",
#        "don't",
#        'thought',
#        'let',
#        'was',
#        'was',
#        'was',
#        'look',
#        'someone',
#        'know',
#        "don't",
#        'said,',
#        'called',
#        'call',
#        'call',
#        'called',
#        'looked',
#        'said,',
#        'called',
#        'call',
#        'call',
#        'called',
#        'someone',
#        'know',
#        "don't",
#        'said,',
#        'called',
#        'call',
#        'called',
#        'call',
#        'call',
#        'call',
#        'call'],
#  "I'm": ['okay',
#          'looking',
#          'calling',
#          'calling',
#          'calling',
#          'calling',
#          'calling',
#          'calling',
#          'wasted',
#          'doing',
#          'doing',
#          'doing'],
#  'If': ['I', 'we', 'we', 'we', 'we', 'we', 'we', 'we', 'we', 'we'],
#  "Let's": ['show',
#            'show',
#            'show',
#            'show',
#            'show',
#            'show',
#            'show',
#            'show',
#            'show',
#            'show',
#            'show',
#            'show',
#            'show',
#            'show',
#            'show',
#            'show',
#            'show',
#            'show',
#            'show'],
#  'Like': ['nothing', "we'd"],
#  'Maybe': ['we'],
#  'Moved': ['to', 'to'],
#  'No': ['we'],
#  'No,': ['I', 'I'],
#  'Now': ["you're", "I'm"],
#  'Of': ['the', 'the', 'the'],
#  'On': ['our'],
#  'Out': ['on', 'on'],
#  'Paris': ['To', 'To', "Let's", '(If', '(If', '(If', '(If', "Let's"],
#  'Posting': ['pictures'],
#  'Pull': ['the', 'the', 'the'],
#  'Rover': ['That', 'That', 'That'],
#  'Say': ['what', 'what'],
#  'Set': ['free'],
#  'Show': ['them', 'them', 'them', 'them'],
#  'So': ['baby', 'baby', 'baby', 'I', 'I', 'I'],
#  'Standing': ['there'],
#  'Stay': ['and'],
#  'That': ['I', 'we', 'I', 'I'],
#  "They'll": ['say', 'say', 'say', 'say', 'say', 'say'],
#  'Things': ['started'],
#  'Think': ['about', 'about'],
#  'To': ['get', 'get'],
#  'Too': ['high'],
#  'Tucson,': ['okay'],
#  'Two': ['kids', 'kids'],
#  'We': ["ain't",
#         "ain't",
#         "ain't",
#         "ain't",
#         "ain't",
#         "ain't",
#         "ain't",
#         "ain't",
#         "ain't",
#         "ain't",
#         "ain't",
#         "ain't",
#         'were',
#         'both',
#         'just',
#         'both',
#         'both',
#         'were',
#         'were',
#         'breathe',
#         'were',
#         'were',
#         'were',
#         'were',
#         'were',
#         'were',
#         "couldn't"],
#  "We'll": ['get', 'get', 'get'],
#  'Went': ['from', 'from', 'from'],
#  'When': ['we', 'you', 'you'],
#  'While': ["I'm"],
#  "Who's": ['gonna'],
#  'Yeah,': ["it's", "it's", 'yeah,', "it's", "it's", 'yeah,'],
#  'You': ['look',
#          'say',
#          'say',
#          'say',
#          'say',
#          'look',
#          'said,',
#          'looked',
#          'said,',
#          'said,'],
#  'a': ['broke', 'hotel', 'broke', 'hotel', 'shot', 'frown', 'cigarette'],
#  'about': ['anything,', 'what', 'what'],
#  'afford': ['Bite', 'Bite', 'Bite'],
#  'again': ['I'],
#  "ain't": ['ever',
#            'ever',
#            'ever',
#            'ever',
#            'ever',
#            'ever',
#            'ever',
#            'ever',
#            'ever',
#            'ever',
#            'ever',
#            'ever',
#            'ever',
#            'ever',
#            'ever',
#            'ever'],
#  'air': ['of'],
#  'all': ['those', 'lead', 'those', 'those', 'around', 'back', 'around', 'back'],
#  'almost': ['fought', 'fought', 'fought'],
#  'an': ['issue'],
#  'and': ["that's", 'play', 'a', 'you', 'I'],
#  'anything': ["They'll", "They'll", "They'll"],
#  'anything,': ['everything'],
#  'are': ['better',
#          'better',
#          'better',
#          'better',
#          'Show',
#          "Let's",
#          'Show',
#          "Let's",
#          'better',
#          'better',
#          'Show',
#          "Let's",
#          'Show',
#          "Let's",
#          'better',
#          'better',
#          'better',
#          'better',
#          'better',
#          'better',
#          'better',
#          'better',
#          'better'],
#  'around': ['Bring', 'Bring'],
#  'as': ['good', 'the'],
#  'at': ['the', 'the', 'the', 'you', 'me', 'me', 'you'],
#  'away': ['from', 'with', 'from', 'with', 'with', 'Broke'],
#  'baby': ['pull', 'pull', 'pull'],
#  'back': ['in', 'in', 'in', 'to', 'to'],
#  'backseat': ['of', 'of', 'of'],
#  'bar': ['And', 'And', "Don't", "Don't", "Don't", 'downtown', 'downtown'],
#  'beat': ['to'],
#  'before': ['I'],
#  'believe': ['in', 'in'],
#  'better': ['than',
#             "Let's",
#             "Let's",
#             'We',
#             "Let's",
#             'We',
#             "Let's",
#             'If',
#             'We',
#             'We',
#             "Let's",
#             'If',
#             'If',
#             'If',
#             "Let's",
#             'Two'],
#  'both': ['know', 'know', 'know', 'know'],
#  'breaks': ['your', 'your'],
#  'breathe': ['in'],
#  'broke': ['down', 'down'],
#  'burn': ['us'],
#  'but': ["I'm",
#          "it's",
#          "it's",
#          "it's",
#          "it's",
#          "it's",
#          "it's",
#          'I',
#          'strangers'],
#  'by': ['yourself'],
#  'call': ['Now', 'you', 'you', 'you', 'you', 'you', 'you', 'you', 'you', 'you'],
#  'called': ['you', 'you', 'you', 'you', 'you', 'you'],
#  'calling': ['you', 'you', 'you', 'you', 'you', 'you'],
#  'calls': ['Now'],
#  'can': ['go', 'go'],
#  "can't": ['stop', 'stop', 'afford', 'stop', 'stop', 'afford', 'afford'],
#  'cannot': ['live', 'live'],
#  'car': ['And', 'And', 'And', 'And', 'And'],
#  'caught': ['up'],
#  'cigarette': ['Posting'],
#  'city': ['in', 'in', 'Drunk', "Don't"],
#  'class': ['for'],
#  'clever': ['If', 'If', 'If'],
#  'closer': ['in', 'in', 'in'],
#  'conversation': ['to', 'to', 'to'],
#  'corner': ['Of', 'Of', 'Of'],
#  'could': ['take', 'work', 'do', 'do', 'do'],
#  "couldn't": ['get', 'feel'],
#  "cuttin'": ['class'],
#  'day': ['I', 'that', 'that', 'that', 'that', 'that', 'that'],
#  'death': ['in'],
#  'destruction': ['At'],
#  'do': ['anything', 'anything', 'anything'],
#  'doing': ['just', 'for', 'tonight"', 'for', 'tonight"', 'for', 'tonight"'],
#  "don't": ['think', 'know', 'wanna', 'even', 'even', 'wanna', 'even'],
#  'down': ['car',
#           'car',
#           'then',
#           'together',
#           'then',
#           'together',
#           'then',
#           'together',
#           'then',
#           'together',
#           'then',
#           'together',
#           'then',
#           'together',
#           "Let's",
#           "Let's",
#           "Let's",
#           'I'],
#  'down)': ['We', 'We', 'We', "Let's"],
#  'downtown': ['When', 'When'],
#  'drink': ['too'],
#  'drugs': ['Too'],
#  'drunk': ['on'],
#  'dysfunction': ['But'],
#  'else"': ['If'],
#  'even': ['know', 'know', 'know'],
#  'ever': ['getting',
#           'getting',
#           'getting',
#           'getting',
#           'getting',
#           'getting',
#           'getting',
#           'getting',
#           'getting',
#           'getting',
#           'getting',
#           'getting',
#           'getting',
#           'getting',
#           'getting',
#           'getting'],
#  'every': ['time'],
#  'everything': ['led', "Let's", "Let's", "Let's"],
#  'fade': ['You'],
#  'fair': ['but'],
#  'fall': ['by'],
#  'far': ['like', 'like', 'like'],
#  'father': ['when', 'when', 'when'],
#  'feel': ['no'],
#  'fine': ['before'],
#  'fire': ["Who's", "Don't"],
#  'for': ['the', 'the', 'the', 'the'],
#  'forget': ['just'],
#  'fought': ['your', 'your', 'your'],
#  'four': ['years,', 'years,'],
#  'free': ['every'],
#  'friends': ['it'],
#  'from': ['this,', 'this,', 'your', 'your', 'one', 'one', 'one'],
#  'frown': ['and'],
#  'get': ['away', 'away', 'away', 'away', 'away', 'higher'],
#  'getting': ['older',
#              'older',
#              'older',
#              'older',
#              'older',
#              'older',
#              'older',
#              'older',
#              'older)',
#              'older',
#              'older)',
#              'older',
#              'older)',
#              'older',
#              'older',
#              'older'],
#  'go': ['like',
#         'from',
#         'too',
#         'from',
#         'too',
#         'too',
#         'down',
#         'down',
#         'down',
#         'down',
#         'down',
#         'down',
#         'down',
#         'down',
#         'down',
#         'down',
#         'down',
#         'down',
#         'down)',
#         'down)',
#         'down)',
#         'down)',
#         'down',
#         'down',
#         'down'],
#  'gonna': ['save'],
#  'good': ['as'],
#  'gotta': ['own', 'own'],
#  'hard': ['when',
#           'when',
#           'when',
#           'when',
#           'when',
#           'when',
#           'when',
#           'when',
#           'when',
#           'when',
#           'when',
#           'when',
#           'when',
#           'when',
#           'when'],
#  'he': ['pushed', 'pushed', 'pushed'],
#  'heart': ['Moved', 'Moved'],
#  'hearts': ['on', 'on'],
#  'high': ['to'],
#  'high,': ['it'],
#  'higher': ['Things'],
#  'hope': ['I', 'that'],
#  'hotel': ['bar', 'bar'],
#  'how': ['to'],
#  'if': ["it's"],
#  'in': ['a',
#         'a',
#         'the',
#         'Boulder',
#         'Tucson,',
#         'a',
#         'a',
#         'the',
#         'Boulder',
#         'the',
#         'Boulder',
#         'the',
#         'the',
#         'the',
#         'the',
#         'Paris',
#         'a',
#         'Paris',
#         'the',
#         'If',
#         'Paris',
#         'Paris',
#         'Paris',
#         'Paris',
#         'Paris',
#         'Paris',
#         'now',
#         'now'],
#  'insane': ['Stay'],
#  'internet': ['Out'],
#  'issue': ['but'],
#  'it': ['was',
#         'breaks',
#         'breaks',
#         'go',
#         'was',
#         'would',
#         'Getting',
#         'burn',
#         'all',
#         'all'],
#  "it's": ['hard',
#           'hard',
#           'hard',
#           'hard',
#           'hard',
#           'over',
#           'hard',
#           'over',
#           'hard',
#           'hard',
#           'over',
#           'hard',
#           'over',
#           'hard',
#           'hard',
#           'hard',
#           'hard',
#           'over',
#           'hard',
#           'over',
#           'hard',
#           'fair'],
#  'just': ['fine', 'why', 'gotta', 'gotta'],
#  'kids': ['with', 'with', 'running', 'running'],
#  'kissed': ['me'],
#  'knew': ['how'],
#  'know': ['it',
#           'you',
#           'it',
#           'you',
#           'you',
#           'I',
#           'that',
#           'I',
#           'I',
#           'if',
#           'I',
#           'what',
#           'what',
#           'I',
#           'what'],
#  'lead': ['to'],
#  'learning': ['to', 'to', 'to'],
#  'least': ['we'],
#  'led': ['to'],
#  'left': ['you,'],
#  'let': ['it', 'you', 'it', 'me', 'the', 'me'],
#  "let's": ['turn', 'turn'],
#  'life?"': ['And', 'And', 'And'],
#  'like': ['this', 'when', 'to', 'when', 'to', 'when', 'to'],
#  'lips': ['on', 'on', 'on'],
#  'live': ['without?', 'without', 'without?', 'without'],
#  "livin'": ['in'],
#  'look': ['as', 'so', 'at', 'at', 'away'],
#  'looked': ['at', 'at'],
#  'looking': ['pretty', 'pretty', 'down'],
#  'love': ['Fought', 'But', 'But', 'But'],
#  'love,': ["we're", "we're", "we're"],
#  'mattress': ['that', 'that', 'that'],
#  'me': ['closer',
#         'closer',
#         'closer',
#         'in',
#         'in',
#         "it's",
#         "it's",
#         'in',
#         "it's",
#         "it's",
#         "it's",
#         "it's",
#         'Like',
#         'walk',
#         'We',
#         'and',
#         'walk'],
#  'meet': ['them', 'up', 'up', 'up'],
#  'memory': ['fade'],
#  'met': ['you', 'you'],
#  'mine': ['And', 'Can', 'And', 'Can', 'And', 'And'],
#  'mine"': ['So', 'Broke', 'So', 'Think', 'So', 'Can'],
#  'mine?': ['And', 'And', 'Can', 'Can', 'Can'],
#  'much': ['and'],
#  'my': ['love,', 'love,', 'love,'],
#  'never': ['see',
#            'regretted',
#            'regretted',
#            'look',
#            'regretted',
#            'regretted',
#            'regretted',
#            'regretted'],
#  'nice': ['to'],
#  'nights': ['we', 'we', 'we'],
#  'no': ['calls', 'call', 'pain'],
#  'nothing': ['but'],
#  'now': ['I', 'Two', 'Am', 'Am'],
#  'now?': ['When'],
#  'of': ['your',
#         'your',
#         'your',
#         'yourself',
#         'this',
#         'it',
#         'your',
#         'your',
#         'your'],
#  'off': ['the', 'the', 'the'],
#  'okay': ['Hey,', 'I'],
#  'older': ['We',
#            'We',
#            'You',
#            'We',
#            'We',
#            'So',
#            'We',
#            '(we',
#            '(we',
#            '(we',
#            'We',
#            'No',
#            'We'],
#  'older)': ['We', 'We', 'We'],
#  'on': ['your',
#         'your',
#         'your',
#         'the',
#         'the',
#         'the',
#         'the',
#         'fire',
#         'fire',
#         'you,',
#         'mine',
#         'the',
#         'mine',
#         'you,',
#         'mine'],
#  'on,': ["let's", "let's"],
#  'one': ['conversation', 'conversation', 'conversation'],
#  'our': ['own'],
#  'out': ['Think', 'on', 'on'],
#  'out"': ['Out'],
#  'out,': ['like', 'like', 'like'],
#  'over': ['Say', 'You', 'Say', 'You', 'You', 'You'],
#  'own': ['that', 'that', "cuttin'"],
#  'pain': ['You'],
#  'parents': ['And', 'You'],
#  'past': ['we'],
#  'pictures': ['of'],
#  'play': ['that'],
#  'pretty': ['in', 'in'],
#  'proud': ['Standing'],
#  'pull': ['me', 'me', 'me'],
#  'pushed': ['me', 'me', 'me'],
#  'regretted': ['the', 'the', 'the', 'the', 'the', 'the'],
#  'rest': ['of', 'of', 'of'],
#  'right': ['off', 'off', 'off', 'now'],
#  'roommate': ['back', 'back', 'back'],
#  'running': ['through', 'through'],
#  'said,': ['"Hey,',
#            '"I',
#            '"I',
#            '"I',
#            '"Hey,',
#            '"I',
#            '"I',
#            '"I',
#            '"Hey,',
#            '"I',
#            '"I',
#            '"I'],
#  'save': ['us'],
#  'say': ['what',
#          'what',
#          'what',
#          'what',
#          'you',
#          'that',
#          'you',
#          'that',
#          'you',
#          'that'],
#  'see': ['them', 'that'],
#  'sheets': ['right', 'right', 'right'],
#  'shit': ["Don't", 'We', 'I'],
#  'shot': ['right'],
#  'shoulder': ['Pull', 'Pull', 'Pull'],
#  'show': ['them',
#           'them',
#           'them',
#           'them',
#           'them',
#           'them',
#           'them',
#           'them',
#           'them',
#           'them',
#           'them',
#           'them',
#           'them',
#           'them',
#           'them',
#           'them',
#           'them',
#           'them',
#           'them'],
#  'small': ['town'],
#  'snuck': ['out,', 'out,', 'out,'],
#  'so': ['young', 'proud'],
#  'someone': ['else"', 'you', 'you'],
#  'song': ['That'],
#  'started': ['looking'],
#  'staying': ['in', 'in', 'in', 'in', 'in', 'in', 'in', 'in'],
#  'stole': ['From', 'From', 'From'],
#  'stop': ['No,', 'So', 'No,', 'So'],
#  'strangers': ['now'],
#  'subway': ['train'],
#  'take': ['this'],
#  'tattoo': ['on', 'on', 'on'],
#  'tell': ['your', 'me', 'me', 'me', 'me', 'me', 'me'],
#  'terrace': ['I', 'We'],
#  'than': ['drugs'],
#  'that': ['tattoo',
#           'you',
#           'Blink-182',
#           'tattoo',
#           'you',
#           'tattoo',
#           'you',
#           'we',
#           'shit',
#           'it',
#           'shit',
#           'shit',
#           'we',
#           'we',
#           'I',
#           'I',
#           'I',
#           'we',
#           'bar',
#           'I',
#           'I',
#           'I',
#           'I',
#           'bar',
#           'I',
#           'I'],
#  "that's": ['an'],
#  'the': ['city',
#          'backseat',
#          'sheets',
#          'corner',
#          'mattress',
#          'day',
#          'city',
#          'backseat',
#          'sheets',
#          'corner',
#          'mattress',
#          'backseat',
#          'sheets',
#          'corner',
#          'mattress',
#          'yard',
#          'bar',
#          'high,',
#          'yard',
#          'bar',
#          'yard',
#          'bar',
#          'terrace',
#          'internet',
#          'terrace',
#          'air',
#          'thrill',
#          'past',
#          'rest',
#          'day',
#          'day',
#          'city',
#          'subway',
#          'city',
#          'memory',
#          'rest',
#          'day',
#          'day',
#          'rest',
#          'day',
#          'day'],
#  'their': ['hearts', 'hearts'],
#  'them': ['But',
#           'again',
#           'we',
#           'we',
#           'we',
#           'we',
#           'we',
#           'we',
#           'we',
#           'we',
#           'we',
#           'we',
#           'we',
#           'we',
#           'we',
#           'we',
#           'we',
#           'we',
#           'we',
#           'we',
#           'we',
#           'we',
#           'we',
#           'we',
#           'we'],
#  'then': ['we', 'we', 'we', 'we', 'we', 'we'],
#  'there': ['with'],
#  'think': ['that'],
#  'this': ['Maybe', 'in', 'out"', 'small', 'all', 'all'],
#  'this,': ['yeah', 'yeah'],
#  'those': ['nights', 'nights', 'nights'],
#  'thought': ['that', '"How', 'that'],
#  'thought,': ['"Wow'],
#  'thrill': ['of'],
#  'through': ['the', 'the'],
#  'time': ['you'],
#  'to': ['meet',
#         'the',
#         'death',
#         'the',
#         'love',
#         'dysfunction',
#         'meet',
#         'love',
#         'see',
#         'destruction',
#         'meet',
#         'love',
#         'meet',
#         'love',
#         'that',
#         'your',
#         'your',
#         'that',
#         'your'],
#  'together': ["They'll", "We'll", "They'll", "We'll", "They'll", "We'll"],
#  'tonight"': ['Went', 'Went', 'Went'],
#  'too': ['much', 'far', 'far', 'far'],
#  'town': ['On'],
#  'train': ['Set'],
#  'turn': ['this', 'this'],
#  'up': ['at', 'in', 'at', 'at'],
#  'up,': ['you', 'you', 'you', 'you', 'you', 'you'],
#  'us': ['now?', 'out'],
#  'walk': ['out', 'out'],
#  'wanna': ['live', 'live'],
#  'want,': ['but', 'but', 'but', 'but', 'but', 'but'],
#  'was': ['doing', 'nice', 'insane', 'better', 'clever', 'clever', 'clever'],
#  'wasted': ['with'],
#  'we': ['beat',
#         "ain't",
#         'thought',
#         'knew',
#         'just',
#         'can',
#         'snuck',
#         'were',
#         'both',
#         'can',
#         'snuck',
#         'snuck',
#         'could',
#         'go',
#         'go',
#         'go',
#         'go',
#         'are',
#         'are',
#         'are',
#         'were',
#         'go',
#         'go',
#         'go',
#         'go',
#         'are',
#         'are',
#         'are',
#         'are',
#         'are',
#         'are',
#         'are',
#         'are',
#         'are',
#         'are',
#         'are',
#         'are',
#         'go',
#         'go',
#         'go',
#         'go',
#         'are',
#         'go',
#         'go',
#         'go',
#         'go',
#         'are',
#         'are',
#         'are',
#         'go',
#         'are',
#         'go',
#         'are',
#         'go',
#         'are',
#         'are',
#         'thought',
#         "couldn't"],
#  "we'd": ['never'],
#  "we're": ['learning', 'learning', 'learning'],
#  'were': ['so',
#           'caught',
#           'staying',
#           'staying',
#           "livin'",
#           'staying',
#           'staying',
#           'staying',
#           'staying',
#           'staying',
#           'staying'],
#  'what': ['you',
#           'you',
#           'you',
#           'you',
#           'you',
#           'you',
#           'you',
#           "I'm",
#           "I'm",
#           'you',
#           "I'm"],
#  'whatcha': ['doing', 'doing', 'doing'],
#  'when': ['we',
#           'I',
#           'he',
#           "you're",
#           "you're",
#           'I',
#           'he',
#           "you're",
#           "you're",
#           "you're",
#           "you're",
#           "you're",
#           'I',
#           'he',
#           "you're",
#           "you're",
#           "you're",
#           "you're",
#           "you're",
#           "you're",
#           "you're",
#           "you're"],
#  'why': ['I'],
#  'with': ['someone',
#           'everything',
#           'a',
#           'everything',
#           'everything',
#           'their',
#           'their'],
#  'without': ['you,', 'you,'],
#  'without?': ["'Cause", "'Cause"],
#  'work': ['this'],
#  'worry,': ['my', 'my', 'my'],
#  'would': ['all'],
#  "wouldn't": ['let', 'let'],
#  'wrecked': ['your', 'your', 'your'],
#  'yard': ['And', 'And', 'And'],
#  'yeah': ['We', 'We', "it's", 'Come', 'You', 'Come', 'You'],
#  'yeah,': ["it's", 'yeah'],
#  'years,': ['no', 'no'],
#  'you': ['I',
#          'tell',
#          "can't",
#          'stole',
#          'I',
#          "can't",
#          'stole',
#          "can't",
#          'stole',
#          'up,',
#          'tell',
#          'want,',
#          'up,',
#          'tell',
#          'want,',
#          'up,',
#          'tell',
#          'want,',
#          'up,',
#          'tell',
#          'want,',
#          'up,',
#          'tell',
#          'want,',
#          'up,',
#          'tell',
#          'want,',
#          'fall',
#          'could',
#          'could',
#          'could',
#          'and',
#          'look',
#          'believe',
#          'cannot',
#          "wouldn't",
#          'said,',
#          'mine"',
#          'mine',
#          'mine?',
#          'said,',
#          'mine"',
#          'kissed',
#          'Like',
#          'said,',
#          'mine"',
#          'mine',
#          'mine?',
#          'said,',
#          'mine"',
#          'believe',
#          'cannot',
#          "wouldn't",
#          'said,',
#          'mine"',
#          'mine',
#          'said,',
#          'mine"',
#          'mine?',
#          'mine?',
#          'mine?',
#          'mine?'],
#  "you're": ['looking',
#             'young',
#             'young',
#             'young',
#             'young',
#             'young',
#             'young',
#             'young',
#             'young',
#             'young',
#             'young',
#             'young',
#             'young',
#             'young',
#             'young',
#             'young'],
#  'you,': ['I', 'yeah', 'yeah', 'yeah', 'yeah'],
#  'young': ['when',
#            'Yeah,',
#            'Caught,',
#            'Yeah,',
#            'Yeah,',
#            "I'm",
#            "I'm",
#            'We',
#            "I'm",
#            "I'm",
#            'Yeah,',
#            'Yeah,',
#            'Yeah,',
#            "I'm",
#            "I'm",
#            'We'],
#  'your': ['friends',
#           'heart',
#           'Rover',
#           'shoulder',
#           'roommate',
#           'heart',
#           'Rover',
#           'shoulder',
#           'roommate',
#           'Rover',
#           'shoulder',
#           'roommate',
#           'car',
#           'father',
#           'car',
#           'father',
#           'car',
#           'father',
#           'parents',
#           'parents',
#           'life?"',
#           'lips',
#           'life?"',
#           'lips',
#           'life?"',
#           'lips'],
#  'yourself': ['While', 'on']}

# %% [markdown]
# ## Generate our song!

# %% [markdown]
# This function returns the Markov dictionary which we'll use to generate our new banger.

# %%
def baby_pull_me_closer(chain):
    #We randomly choose our first word that already exists, so it is able to generate the rest after.
    #Because numpy's random.choice function can only read in a list, we need to convert our keys from our dictionary into a list format
    song = ""
    first = np.random.choice(list(chain.keys()))
    song += first

    while len(song.split()) < number_of_words:
        #Although a true Markov model would use weights and probability ditribution for selecting the subsequent words, 
        #using numpy's random choice gives us more variety in a smaller data set as to avoid mimicking the lyrics too closely
        next_word = np.random.choice(list(chain[first]))
        first = next_word
        
        #formatting for a song
        line_break = np.random.randint(low=1, high=100)
        if line_break < 20:
            song += "\n" + next_word
        elif line_break < 10:
            song += "\n\n" + next_word
        else:
            song += " " + next_word
            
    
    print(song)

# %%
song = load_file()
chain = build_chain(song)
baby_pull_me_closer(chain)
# Out:
# No, I want something
# just why
# I call
# you want, but it's hard when
# you're young Yeah, it's over Say
# what I'm calling
# you
# tell me closer in Paris (If
# we go down together
# We'll
# get away from
# this, yeah We
# were staying in the mattress that tattoo on the bar downtown
# When we are
# better Two kids running through the high, it Getting
# drunk on the mattress
# that
# it was
# clever If
# we snuck
# out, like this
# Doo-doo-doo, doo-doo-doo Doo-doo-doo, doo-doo-doo Oh, I call you
# want, but it's hard when you're looking for the corner Of
# the city Drunk
# on the
# bar Don't let it all around Bring
# it was clever If
# we are Let's
# show them we could
# take this out"
# Out
# on the day that I want something just like to meet
# up in Paris (If we go down) We were staying in the bar
# Don't let
# me closer in Paris Let's show them we
# are Let's show
# them we are Show
# them we go down I
# never
# see them we are Let's show them again I called you
# wanna go? How
# much you
# cannot live without
# you, yeah We ain't ever getting
# older
# So I drink too
# far
# like when you're young Yeah, it's over
# You said, where'd you stole From your car And you kissed me and its eclipse And you mine? Can I
# know I want something just like to meet up at the mattress that I call you want,
# but
# it's hard when I know that list
# But I can't stop So baby pull me closer in Paris
# To get away with their
# hearts on fire Don't worry,
# my love, we're learning to
